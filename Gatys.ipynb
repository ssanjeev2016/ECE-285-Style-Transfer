# %%
# %matplotlib notebook
import os
import numpy as np
import torch
from torch import nn
from torch.nn import functional as F
import torch.utils.data as td
import torchvision as tv
import pandas as pd
from PIL import Image
from matplotlib import pyplot as plt

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
import nntools as nt

# %%
class NNClassifier(nt.NeuralNetwork):
    def __init__(self):
        super(NNClassifier, self).__init__()
        self.MSE = nn.MSELoss()
    def criterion(self, y, d):
        return self.MSE(y, d)

# %%
vgg = tv.models.vgg19(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /tmp/xdg-cache/torch/checkpoints/vgg19-dcbb9e9d.pth
# 100%|██████████| 548M/548M [00:02<00:00, 269MB/s]

# %%
print(vgg)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
# Define the network with transfer learning

class VGG19Transfer(NNClassifier):
    def __init__(self, fine_tuning=False): #want to keep existing weights/biases
        super(VGG19Transfer, self).__init__()
        vgg = tv.models.vgg19(pretrained=True)
        for param in vgg.parameters():
            param.requires_grad = fine_tuning
        
        # Only maintain the feature space    
        self.net = nn.ModuleList()
        self.net = vgg.features
        # Change MaxPool to AvgPool
        self.net[4] = nn.AvgPool2d(kernel_size=2, stride=2, padding=0, ceil_mode=False)
        self.net[9] = nn.AvgPool2d(kernel_size=2, stride=2, padding=0, ceil_mode=False)
        self.net[18] = nn.AvgPool2d(kernel_size=2, stride=2, padding=0, ceil_mode=False)
        self.net[27] = nn.AvgPool2d(kernel_size=2, stride=2, padding=0, ceil_mode=False)
        self.net[36] = nn.AvgPool2d(kernel_size=2, stride=2, padding=0, ceil_mode=False)
 
    def forward(self, x):
        
        #FIX!
        rep = {}
#         features = [self.vgg[:4](x)] + [self.vgg[:7](x)] + [self.vgg[:12](x)] + [self.vgg[:21](x)] + [self.vgg[:30](x)]
#       
        #Conv2d
        rep['1_1'] = self.net[0:2](x)
        
        a = self.net[2:6](rep['1_1'])
        rep['2_1'] = self.net[6](a)
        
        a = self.net[7:11](rep['2_1'])
        rep['3_1'] = self.net[11](a)
        
        a = self.net[12:20](rep['3_1'])
        rep['4_1'] = self.net[20](a)
        
        a = self.net[21:22](rep['4_1'])
        rep['4_2'] = self.net[22](a)
        
        a = self.net[23:29](rep['4_2'])
        rep['5_1'] = self.net[29](a)

##relus
#         a = self.net[0:1](x)
#         rep['1_1'] = self.net[2](a)
        
#         a = self.net[3:8](rep['1_1'])
#         rep['2_1'] = self.net[9](a)
        
#         a = self.net[10:15](rep['2_1'])
#         rep['3_1'] = self.net[16](a)
        
#         a = self.net[17:28](rep['3_1'])
#         rep['4_1'] = self.net[29](a)
        
#         a = self.net[30:31](rep['4_1'])
#         rep['4_2'] = self.net[32](a)
        
#         a = self.net[33:44](rep['4_2'])
#         rep['5_1'] = self.net[45](a)

        return rep #dictionary data structure; can change if you guys have better ideas

# %%
def myimshow(image, ax=plt):
    image = image.to('cpu').numpy()
    image = np.moveaxis(image, [0, 1, 2], [2, 0, 1])
    image = (image + 1) / 2
    image[image < 0] = 0
    
    image[image > 1] = 1
    h = ax.imshow(image)
    ax.axis('off')
    return h

# %%
# net = VGG19Transfer()

# print(net)

# %%
# get images
transform = tv.transforms.Compose([
#     tv.transforms.Resize((500, 500)), #whatever size we want i guess?
    tv.transforms.ToTensor(),
#             tv.transforms.Normalize((0,0,0),(1,1,1)),
    tv.transforms.Normalize((.5,.5,.5),(.5,.5,.5)) #given range [0,1] for all channels
    ])

photo_path = 'photo.jpg'
photo = Image.open(photo_path)
p = transform(photo)
p = p[None,:,:,:]

art_path = 'art.jpg'
art = Image.open(art_path)
a = transform(art)
a = a[None,:,:,:]

x = torch.randn(3,500,500,requires_grad=True) # to allow updates!!
x = x[None,:,:,:]

# %%
x.shape
# Out:
# torch.Size([1, 3, 500, 500])

# %%
# get feature representations of artwork and photograph
# v = VGG19Transfer()
# P = v.forward(p)
# A = v.forward(a)

# %%
# A = v.forward(a)

# %%
# A['5_1'].shape

# %%
# Photograph feature response reshaped matrix (capital P^l)
# P1 = P['1'].view(64,-1)
# P2 = P['2'].view(128,-1)
# P3 = P['3'].view(256,-1)
# P4 = P['4'].view(512,-1)
# P5 = P['5'].view(512,-1)

# %%
# Artwork feature response reshaped matrix (capital A^l)
# A1 = A['1'].view(64,-1)
# A2 = A['2'].view(128,-1)
# A3 = A['3'].view(256,-1)
# A4 = A['4'].view(512,-1)
# A5 = A['5'].view(512,-1)

# %%
def Gram(featresp):
    return torch.mm(featresp,featresp.t()) # NlxNl (from paper)

# %%
def bruh(photo,art,net,epochs,lr=.01):
    
    h = photo.shape[2]
    w = photo.shape[3]
    x = torch.randn(1,3,h,w,requires_grad=True,device='cuda')  
    
    optimizer = torch.optim.Adam([x], lr=lr)
    
    P = net.forward(photo)
    P42NL = P['4_2'].shape[1]
    P42 = P['4_2'].view(P42NL,-1)

    
    A = net.forward(art) 
    A1 = A['1_1'].view(64,-1)
    A2 = A['2_1'].view(128,-1)
    A3 = A['3_1'].view(256,-1)
    A4 = A['4_1'].view(512,-1)
    A5 = A['5_1'].view(512,-1)
    
    
    
    for epoch in range(epochs):
        optimizer.zero_grad()
        
        outputs = net.forward(x)
        
        out42 = outputs['4_2'].view(P42NL, -1)
        
        out1 = outputs['1_1'].view(64,-1)
        out2 = outputs['2_1'].view(128,-1)
        out3 = outputs['3_1'].view(256,-1)
        out4 = outputs['4_1'].view(512,-1)
        out5 = outputs['5_1'].view(512,-1)

        #get content loss
        #define criterion
        contentloss = ((out42-P42)**2).sum() / 2
        
        #get style gram matrices
        gram1 = Gram(out1)
        gram2 = Gram(out2)
        gram3 = Gram(out3)
        gram4 = Gram(out4)
        gram5 = Gram(out5)
        
        gram1o = Gram(A1)
        gram2o = Gram(A2)
        gram3o = Gram(A3)
        gram4o = Gram(A4)
        gram5o = Gram(A5)
        
#         #style loss
        E1 = 1/(4*(out1.shape[0])**2*(out1.shape[1])**2) * ((gram1-gram1o)**2).sum() #net.criterion(gram1,gram1o)
        E2 = 1/(4*(out2.shape[0])**2*(out2.shape[1])**2) * ((gram2-gram2o)**2).sum() #net.criterion(gram2,gram2o)
        E3 = 1/(4*(out3.shape[0])**2*(out3.shape[1])**2) * ((gram3-gram3o)**2).sum() #net.criterion(gram3,gram3o)
        E4 = 1/(4*(out4.shape[0])**2*(out4.shape[1])**2) * ((gram4-gram4o)**2).sum() #net.criterion(gram4,gram4o)
        E5 = 1/(4*(out5.shape[0])**2*(out5.shape[1])**2) * ((gram5-gram5o)**2).sum() #net.criterion(gram5,gram5o)
        
        #total style loss
        styleloss = (E1+E2+E3+E4+E5)/5
        
        #get total loss
        loss = contentloss + 1000*styleloss
        
        #backprop
        loss.backward(retain_graph=True)
        
        #parameter search
        optimizer.step()
        if epoch % 25 == 0:
            print(loss)
            print(epoch)

#         x[0,0,0:250,0:250] = 1
    return x

# %%
# get images
transform = tv.transforms.Compose([
#     tv.transforms.Resize((500, 500)), #whatever size we want i guess?
    tv.transforms.ToTensor(),
#             tv.transforms.Normalize((0,0,0),(1,1,1)),
    tv.transforms.Normalize((.5,.5,.5),(.5,.5,.5)) #given range [0,1] for all channels
    ])

photo_path = 'photo.jpg'
photo = Image.open(photo_path)
p = transform(photo)
p = p[None,:,:,:]

art_path = 'art.jpg'
art = Image.open(art_path)
a = transform(art)
a = a[None,:,:,:]

# x = torch.randn(3,500,500,requires_grad=True) # to allow updates!!
# x = x[None,:,:,:]

# %%
p = p.to(device)
a = a.to(device)
v = VGG19Transfer().to(device)

# %%
aa = bruh(p,a,v,5000)
# Out:
# tensor(89354.5781, device='cuda:0', grad_fn=<AddBackward0>)
# 0
# tensor(59752.0820, device='cuda:0', grad_fn=<AddBackward0>)
# 25
# tensor(40405.5234, device='cuda:0', grad_fn=<AddBackward0>)
# 50
# tensor(26268.0352, device='cuda:0', grad_fn=<AddBackward0>)
# 75
# tensor(18367.6758, device='cuda:0', grad_fn=<AddBackward0>)
# 100
# tensor(13800.2676, device='cuda:0', grad_fn=<AddBackward0>)
# 125
# tensor(10770.0361, device='cuda:0', grad_fn=<AddBackward0>)
# 150
# tensor(8729.2217, device='cuda:0', grad_fn=<AddBackward0>)
# 175
# tensor(7221.1958, device='cuda:0', grad_fn=<AddBackward0>)
# 200
# tensor(6087.7075, device='cuda:0', grad_fn=<AddBackward0>)
# 225
# tensor(5242.3960, device='cuda:0', grad_fn=<AddBackward0>)
# 250
# tensor(4594.8975, device='cuda:0', grad_fn=<AddBackward0>)
# 275
# tensor(4090.7397, device='cuda:0', grad_fn=<AddBackward0>)
# 300
# tensor(3685.4812, device='cuda:0', grad_fn=<AddBackward0>)
# 325
# tensor(3353.5842, device='cuda:0', grad_fn=<AddBackward0>)
# 350
# tensor(3083.8889, device='cuda:0', grad_fn=<AddBackward0>)
# 375
# tensor(2857.2117, device='cuda:0', grad_fn=<AddBackward0>)
# 400
# tensor(2658.1411, device='cuda:0', grad_fn=<AddBackward0>)
# 425
# tensor(2482.8035, device='cuda:0', grad_fn=<AddBackward0>)
# 450
# tensor(2328.4871, device='cuda:0', grad_fn=<AddBackward0>)
# 475
# tensor(2188.7803, device='cuda:0', grad_fn=<AddBackward0>)
# 500
# tensor(2065.8311, device='cuda:0', grad_fn=<AddBackward0>)
# 525
# tensor(1953.5763, device='cuda:0', grad_fn=<AddBackward0>)
# 550
# tensor(1851.4142, device='cuda:0', grad_fn=<AddBackward0>)
# 575
# tensor(1757.5339, device='cuda:0', grad_fn=<AddBackward0>)
# 600
# tensor(1672.0187, device='cuda:0', grad_fn=<AddBackward0>)
# 625
# tensor(1593.9744, device='cuda:0', grad_fn=<AddBackward0>)
# 650
# tensor(1522.5466, device='cuda:0', grad_fn=<AddBackward0>)
# 675
# tensor(1457.0129, device='cuda:0', grad_fn=<AddBackward0>)
# 700
# tensor(1394.3698, device='cuda:0', grad_fn=<AddBackward0>)
# 725
# tensor(1332.2222, device='cuda:0', grad_fn=<AddBackward0>)
# 750
# tensor(1267.8802, device='cuda:0', grad_fn=<AddBackward0>)
# 775
# tensor(1212.6509, device='cuda:0', grad_fn=<AddBackward0>)
# 800
# tensor(1164.0315, device='cuda:0', grad_fn=<AddBackward0>)
# 825
# tensor(1120.4197, device='cuda:0', grad_fn=<AddBackward0>)
# 850
# tensor(1077.1449, device='cuda:0', grad_fn=<AddBackward0>)
# 875
# tensor(1038.0948, device='cuda:0', grad_fn=<AddBackward0>)
# 900
# tensor(1002.2130, device='cuda:0', grad_fn=<AddBackward0>)
# 925
# tensor(968.9803, device='cuda:0', grad_fn=<AddBackward0>)
# 950
# tensor(937.8963, device='cuda:0', grad_fn=<AddBackward0>)
# 975
# tensor(908.2157, device='cuda:0', grad_fn=<AddBackward0>)
# 1000
# tensor(880.5690, device='cuda:0', grad_fn=<AddBackward0>)
# 1025
# tensor(854.6399, device='cuda:0', grad_fn=<AddBackward0>)
# 1050
# tensor(830.3690, device='cuda:0', grad_fn=<AddBackward0>)
# 1075
# tensor(807.7656, device='cuda:0', grad_fn=<AddBackward0>)
# 1100
# tensor(786.6250, device='cuda:0', grad_fn=<AddBackward0>)
# 1125
# tensor(766.6254, device='cuda:0', grad_fn=<AddBackward0>)
# 1150
# tensor(747.5812, device='cuda:0', grad_fn=<AddBackward0>)
# 1175
# tensor(729.0844, device='cuda:0', grad_fn=<AddBackward0>)
# 1200
# tensor(711.6738, device='cuda:0', grad_fn=<AddBackward0>)
# 1225
# tensor(695.2511, device='cuda:0', grad_fn=<AddBackward0>)
# 1250
# tensor(679.4630, device='cuda:0', grad_fn=<AddBackward0>)
# 1275
# tensor(664.0366, device='cuda:0', grad_fn=<AddBackward0>)
# 1300
# tensor(649.2838, device='cuda:0', grad_fn=<AddBackward0>)
# 1325
# tensor(635.1893, device='cuda:0', grad_fn=<AddBackward0>)
# 1350
# tensor(621.9421, device='cuda:0', grad_fn=<AddBackward0>)
# 1375
# tensor(609.3301, device='cuda:0', grad_fn=<AddBackward0>)
# 1400
# tensor(597.2332, device='cuda:0', grad_fn=<AddBackward0>)
# 1425
# tensor(585.1412, device='cuda:0', grad_fn=<AddBackward0>)
# 1450
# tensor(573.4352, device='cuda:0', grad_fn=<AddBackward0>)
# 1475
# tensor(562.2958, device='cuda:0', grad_fn=<AddBackward0>)
# 1500
# tensor(551.7176, device='cuda:0', grad_fn=<AddBackward0>)
# 1525
# tensor(541.4644, device='cuda:0', grad_fn=<AddBackward0>)
# 1550
# tensor(531.4045, device='cuda:0', grad_fn=<AddBackward0>)
# 1575
# tensor(521.5511, device='cuda:0', grad_fn=<AddBackward0>)
# 1600
# tensor(511.9450, device='cuda:0', grad_fn=<AddBackward0>)
# 1625
# tensor(502.2878, device='cuda:0', grad_fn=<AddBackward0>)
# 1650
# tensor(493.0176, device='cuda:0', grad_fn=<AddBackward0>)
# 1675
# tensor(484.0155, device='cuda:0', grad_fn=<AddBackward0>)
# 1700
# tensor(475.4294, device='cuda:0', grad_fn=<AddBackward0>)
# 1725
# tensor(467.2493, device='cuda:0', grad_fn=<AddBackward0>)
# 1750
# tensor(459.5028, device='cuda:0', grad_fn=<AddBackward0>)
# 1775
# tensor(451.5981, device='cuda:0', grad_fn=<AddBackward0>)
# 1800
# tensor(444.1083, device='cuda:0', grad_fn=<AddBackward0>)
# 1825
# tensor(436.4286, device='cuda:0', grad_fn=<AddBackward0>)
# 1850
# tensor(428.9150, device='cuda:0', grad_fn=<AddBackward0>)
# 1875
# tensor(421.7230, device='cuda:0', grad_fn=<AddBackward0>)
# 1900
# tensor(415.0635, device='cuda:0', grad_fn=<AddBackward0>)
# 1925
# tensor(408.2469, device='cuda:0', grad_fn=<AddBackward0>)
# 1950
# tensor(401.3297, device='cuda:0', grad_fn=<AddBackward0>)
# 1975
# tensor(394.8696, device='cuda:0', grad_fn=<AddBackward0>)
# 2000
# tensor(388.0182, device='cuda:0', grad_fn=<AddBackward0>)
# 2025
# tensor(381.6796, device='cuda:0', grad_fn=<AddBackward0>)
# 2050
# tensor(375.4172, device='cuda:0', grad_fn=<AddBackward0>)
# 2075
# tensor(369.7579, device='cuda:0', grad_fn=<AddBackward0>)
# 2100
# tensor(363.9309, device='cuda:0', grad_fn=<AddBackward0>)
# 2125
# tensor(359.0572, device='cuda:0', grad_fn=<AddBackward0>)
# 2150
# tensor(353.7453, device='cuda:0', grad_fn=<AddBackward0>)
# 2175
# tensor(349.2709, device='cuda:0', grad_fn=<AddBackward0>)
# 2200
# tensor(343.7081, device='cuda:0', grad_fn=<AddBackward0>)
# 2225
# tensor(338.9086, device='cuda:0', grad_fn=<AddBackward0>)
# 2250
# tensor(334.1025, device='cuda:0', grad_fn=<AddBackward0>)
# 2275
# tensor(329.0692, device='cuda:0', grad_fn=<AddBackward0>)
# 2300
# tensor(324.7928, device='cuda:0', grad_fn=<AddBackward0>)
# 2325
# tensor(320.7246, device='cuda:0', grad_fn=<AddBackward0>)
# 2350
# tensor(316.9410, device='cuda:0', grad_fn=<AddBackward0>)
# 2375
# tensor(312.0754, device='cuda:0', grad_fn=<AddBackward0>)
# 2400
# tensor(307.9422, device='cuda:0', grad_fn=<AddBackward0>)
# 2425
# tensor(305.4020, device='cuda:0', grad_fn=<AddBackward0>)
# 2450
# tensor(300.8730, device='cuda:0', grad_fn=<AddBackward0>)
# 2475
# tensor(297.0519, device='cuda:0', grad_fn=<AddBackward0>)
# 2500
# tensor(293.8074, device='cuda:0', grad_fn=<AddBackward0>)
# 2525
# tensor(290.1693, device='cuda:0', grad_fn=<AddBackward0>)
# 2550
# tensor(286.6290, device='cuda:0', grad_fn=<AddBackward0>)
# 2575
# tensor(283.9426, device='cuda:0', grad_fn=<AddBackward0>)
# 2600
# tensor(280.7784, device='cuda:0', grad_fn=<AddBackward0>)
# 2625
# tensor(277.0187, device='cuda:0', grad_fn=<AddBackward0>)
# 2650
# tensor(274.1811, device='cuda:0', grad_fn=<AddBackward0>)
# 2675
# tensor(271.1243, device='cuda:0', grad_fn=<AddBackward0>)
# 2700
# tensor(267.9785, device='cuda:0', grad_fn=<AddBackward0>)
# 2725
# tensor(264.9862, device='cuda:0', grad_fn=<AddBackward0>)
# 2750
# tensor(261.6076, device='cuda:0', grad_fn=<AddBackward0>)
# 2775
# tensor(258.8445, device='cuda:0', grad_fn=<AddBackward0>)
# 2800
# tensor(256.5772, device='cuda:0', grad_fn=<AddBackward0>)
# 2825
# tensor(253.8898, device='cuda:0', grad_fn=<AddBackward0>)
# 2850
# tensor(250.6393, device='cuda:0', grad_fn=<AddBackward0>)
# 2875
# tensor(245.1894, device='cuda:0', grad_fn=<AddBackward0>)
# 2900
# tensor(241.9158, device='cuda:0', grad_fn=<AddBackward0>)
# 2925
# tensor(239.6790, device='cuda:0', grad_fn=<AddBackward0>)
# 2950
# tensor(235.9300, device='cuda:0', grad_fn=<AddBackward0>)
# 2975
# tensor(233.9641, device='cuda:0', grad_fn=<AddBackward0>)
# 3000
# tensor(231.1713, device='cuda:0', grad_fn=<AddBackward0>)
# 3025
# tensor(228.2309, device='cuda:0', grad_fn=<AddBackward0>)
# 3050
# tensor(227.0436, device='cuda:0', grad_fn=<AddBackward0>)
# 3075
# tensor(224.0647, device='cuda:0', grad_fn=<AddBackward0>)
# 3100
# tensor(220.8568, device='cuda:0', grad_fn=<AddBackward0>)
# 3125
# tensor(219.6268, device='cuda:0', grad_fn=<AddBackward0>)
# 3150
# tensor(216.8815, device='cuda:0', grad_fn=<AddBackward0>)
# 3175
# tensor(214.8666, device='cuda:0', grad_fn=<AddBackward0>)
# 3200
# tensor(215.6832, device='cuda:0', grad_fn=<AddBackward0>)
# 3225
# tensor(211.0356, device='cuda:0', grad_fn=<AddBackward0>)
# 3250
# tensor(209.1591, device='cuda:0', grad_fn=<AddBackward0>)
# 3275
# tensor(207.4083, device='cuda:0', grad_fn=<AddBackward0>)
# 3300
# tensor(205.9517, device='cuda:0', grad_fn=<AddBackward0>)
# 3325
# tensor(204.3003, device='cuda:0', grad_fn=<AddBackward0>)
# 3350
# tensor(202.0640, device='cuda:0', grad_fn=<AddBackward0>)
# 3375
# tensor(200.9238, device='cuda:0', grad_fn=<AddBackward0>)
# 3400
# tensor(197.8510, device='cuda:0', grad_fn=<AddBackward0>)
# 3425
# tensor(198.0443, device='cuda:0', grad_fn=<AddBackward0>)
# 3450
# tensor(195.5267, device='cuda:0', grad_fn=<AddBackward0>)
# 3475
# tensor(194.9467, device='cuda:0', grad_fn=<AddBackward0>)
# 3500
# tensor(193.4840, device='cuda:0', grad_fn=<AddBackward0>)
# 3525
# tensor(190.1624, device='cuda:0', grad_fn=<AddBackward0>)
# 3550
# tensor(188.7065, device='cuda:0', grad_fn=<AddBackward0>)
# 3575
# tensor(187.3481, device='cuda:0', grad_fn=<AddBackward0>)
# 3600
# tensor(186.9326, device='cuda:0', grad_fn=<AddBackward0>)
# 3625
# tensor(184.4569, device='cuda:0', grad_fn=<AddBackward0>)
# 3650
# tensor(184.7145, device='cuda:0', grad_fn=<AddBackward0>)
# 3675
# tensor(182.3828, device='cuda:0', grad_fn=<AddBackward0>)
# 3700
# tensor(181.0358, device='cuda:0', grad_fn=<AddBackward0>)
# 3725
# tensor(180.5655, device='cuda:0', grad_fn=<AddBackward0>)
# 3750
# tensor(178.1434, device='cuda:0', grad_fn=<AddBackward0>)
# 3775
# tensor(177.5063, device='cuda:0', grad_fn=<AddBackward0>)
# 3800
# tensor(176.1375, device='cuda:0', grad_fn=<AddBackward0>)
# 3825
# tensor(173.8257, device='cuda:0', grad_fn=<AddBackward0>)
# 3850
# tensor(174.2809, device='cuda:0', grad_fn=<AddBackward0>)
# 3875
# tensor(173.0449, device='cuda:0', grad_fn=<AddBackward0>)
# 3900
# tensor(171.1501, device='cuda:0', grad_fn=<AddBackward0>)
# 3925
# tensor(169.6710, device='cuda:0', grad_fn=<AddBackward0>)
# 3950
# tensor(170.0217, device='cuda:0', grad_fn=<AddBackward0>)
# 3975
# tensor(167.1539, device='cuda:0', grad_fn=<AddBackward0>)
# 4000
# tensor(166.4465, device='cuda:0', grad_fn=<AddBackward0>)
# 4025
# tensor(165.5591, device='cuda:0', grad_fn=<AddBackward0>)
# 4050
# tensor(164.0929, device='cuda:0', grad_fn=<AddBackward0>)
# 4075
# tensor(163.3295, device='cuda:0', grad_fn=<AddBackward0>)
# 4100
# tensor(163.9775, device='cuda:0', grad_fn=<AddBackward0>)
# 4125
# tensor(161.1262, device='cuda:0', grad_fn=<AddBackward0>)
# 4150
# tensor(161.1146, device='cuda:0', grad_fn=<AddBackward0>)
# 4175
# tensor(159.4990, device='cuda:0', grad_fn=<AddBackward0>)
# 4200
# tensor(158.9762, device='cuda:0', grad_fn=<AddBackward0>)
# 4225
# tensor(157.1119, device='cuda:0', grad_fn=<AddBackward0>)
# 4250
# tensor(157.1094, device='cuda:0', grad_fn=<AddBackward0>)
# 4275
# tensor(155.4727, device='cuda:0', grad_fn=<AddBackward0>)
# 4300
# tensor(156.0432, device='cuda:0', grad_fn=<AddBackward0>)
# 4325
# tensor(154.6016, device='cuda:0', grad_fn=<AddBackward0>)
# 4350
# tensor(152.9301, device='cuda:0', grad_fn=<AddBackward0>)
# 4375
# tensor(152.9657, device='cuda:0', grad_fn=<AddBackward0>)
# 4400
# tensor(151.9524, device='cuda:0', grad_fn=<AddBackward0>)
# 4425
# tensor(150.5216, device='cuda:0', grad_fn=<AddBackward0>)
# 4450
# tensor(150.2620, device='cuda:0', grad_fn=<AddBackward0>)
# 4475
# tensor(148.5157, device='cuda:0', grad_fn=<AddBackward0>)
# 4500
# tensor(148.4333, device='cuda:0', grad_fn=<AddBackward0>)
# 4525
# tensor(147.8603, device='cuda:0', grad_fn=<AddBackward0>)
# 4550
# tensor(148.5583, device='cuda:0', grad_fn=<AddBackward0>)
# 4575
# tensor(144.9537, device='cuda:0', grad_fn=<AddBackward0>)
# 4600
# tensor(145.6407, device='cuda:0', grad_fn=<AddBackward0>)
# 4625
# tensor(144.5994, device='cuda:0', grad_fn=<AddBackward0>)
# 4650
# tensor(143.4625, device='cuda:0', grad_fn=<AddBackward0>)
# 4675
# tensor(143.3329, device='cuda:0', grad_fn=<AddBackward0>)
# 4700
# tensor(142.4333, device='cuda:0', grad_fn=<AddBackward0>)
# 4725
# tensor(142.4309, device='cuda:0', grad_fn=<AddBackward0>)
# 4750
# tensor(141.4187, device='cuda:0', grad_fn=<AddBackward0>)
# 4775
# tensor(139.3406, device='cuda:0', grad_fn=<AddBackward0>)
# 4800
# tensor(141.4520, device='cuda:0', grad_fn=<AddBackward0>)
# 4825
# tensor(139.1376, device='cuda:0', grad_fn=<AddBackward0>)
# 4850
# tensor(137.9446, device='cuda:0', grad_fn=<AddBackward0>)
# 4875
# tensor(138.0005, device='cuda:0', grad_fn=<AddBackward0>)
# 4900
# tensor(135.9464, device='cuda:0', grad_fn=<AddBackward0>)
# 4925
# tensor(136.2180, device='cuda:0', grad_fn=<AddBackward0>)
# 4950
# tensor(135.4309, device='cuda:0', grad_fn=<AddBackward0>)
# 4975

# %%
aaa = (aa.detach().cpu())
h = aa.shape[2]
aaa = aaa.view(3,h,-1)
myimshow(aaa)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
myimshow(p.view(3,h,-1))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
hh = a.shape[2]
myimshow(a.view(3,hh,-1))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.subplot(1, 2, 1)
myimshow(p.view(3,h,-1))
plt.subplot(1, 2, 2)
hh = a.shape[2]
myimshow(a.view(3,hh,-1))

# %%
imgplot = plt.imshow(aaa.moveaxis([0,1,2],[1,2,0]))

# %%
import glob
from PIL import Image

images=glob.glob("/root/data/amz//train_small/*jpg")
for image in images:
img = Image.open(image)
trans = transforms.ToPILImage()
trans1 = transforms.ToTensor()
plt.imshow(trans(trans1(img)))

# %%
# a = v.parameters()
# list(a)
# print(list(v.parameters()))
v = VGG19Transfer(x)

# %%
#test visualization of feature representation
b = P['1']
bb = b[0,0,:,:].detach() #2nd axis is different feature map of layer defined above as b = g['layernumber']
bb.numpy()
plt.imshow(bb.numpy()) # look at the feature map!
